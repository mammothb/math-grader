# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import sys

sys.path.append(str(Path.cwd().parent))

# %%
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import numpy as np

from src.equation_generator import EquationGenerator
from src.bounding_box import get_bounding_box

# %matplotlib inline

# %%
data_dir = Path.cwd().parent / "data" / "CROHME"

# %%
generator = EquationGenerator(data_dir=data_dir, output_size=(640, 236),
                              char_spacing=8)

# %%
image, coords, equation = generator.generate_equation("1*2/4-20=3")
fig, axes = plt.subplots(1, 1, figsize=(12, 4))
axes.imshow(image, cmap="gray")

# %%
boxes = get_bounding_box(np.array(image))
fig,ax = plt.subplots(1, figsize=(10, 5))
ax.imshow(image, cmap="gray")

for left, top, width, height in boxes:
    print(left, top, width, height)
    rect = patches.Rectangle((left, top), width, height,
                             linewidth=1, edgecolor="r",
                             facecolor="none")
    ax.add_patch(rect)
# Out:
# 77 94 9 49
# 113 94 42 49
# 163 94 49 49
# 216 101 49 35
# 280 94 27 49
# 322 114 49 9
# 377 94 44 49
# 428 96 49 45
# 481 102 49 33
# 545 94 27 49
